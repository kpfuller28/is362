# %% [markdown]
# ### Dataset #1: Olympic Medalists
#
# This dataset is taken from Wikipedia's table of Summer Olympic medalists, available at this [link](https://en.wikipedia.org/wiki/Lists_of_Olympic_medalists). The first challenge I ran into was figuring out the best way to get the data from the table on Wikipedia. I didn’t want to dive too deep into other Python packages or libraries since we’re mostly focusing on **pandas** right now. I tried the **pandas** built-in function `read_html()`, but I received an HTTP 403 error. I searched for a workaround and found that some people had success using the **requests** library, but I wasn’t able to get `read_html()` to properly parse the text of the request object. I eventually took a manual approach and copied the table directly into Excel, then saved it as a CSV for easier use. I think **BeautifulSoup** would be helpful here, but since it looks like we’ll cover that later, I wanted to stay within the scope of this project.

# %%
import pandas as pd


medalists_untidy = pd.read_csv("Summer Olympic Medalists CSV.csv")

medalists_untidy.head(10)
# Out:
#   Discipline (link to medalists list)                    Contested  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                             Archery  1900–1908; 1920; since 1972
# 3                   Artistic swimming                   Since 1984
# 4                                 NaN                          NaN
# 5                           Athletics                   Since 1896
# 6                        (men, women)                          NaN
# 7                           Badminton                   Since 1992
# 8                                 NaN                          NaN
# 9                                 NaN                          NaN
#
#                     Number of    Unnamed: 3               Medals awarded  \
# 0                    Olympics  Medal events  1st place, gold medalist(s)
# 1  (up to conclusion of 2024)     (in 2024)                          NaN
# 2                          18             5                           76
# 3                          11             2                           22
# 4                         NaN           NaN                          NaN
# 5                          30            48                         1075
# 6                         NaN           NaN                          NaN
# 7                           9             5                           44
# 8                         NaN           NaN                          NaN
# 9                         NaN           NaN                          NaN
#
#                       Unnamed: 5                     Unnamed: 6 Unnamed: 7  \
# 0  2nd place, silver medalist(s)  3rd place, bronze medalist(s)      Total
# 1                            NaN                            NaN        NaN
# 2                             74                             66        216
# 3                             20                             21         63
# 4                            NaN                            NaN        NaN
# 5                           1084                           1073       3232
# 6                            NaN                            NaN        NaN
# 7                             44                             48        136
# 8                            NaN                            NaN        NaN
# 9                            NaN                            NaN        NaN
#
#      Athlete(s) with the most medals Athlete(s) with the most gold medals
# 0               (gold–silver–bronze)                                  NaN
# 1                                NaN                                  NaN
# 2     Hubert van Innis (BEL) (6–3–0)       Hubert van Innis (BEL) (6–3–0)
# 3   Svetlana Romashina (RUS) (7–0–0)     Svetlana Romashina (RUS) (7–0–0)
# 4        Huang Xuechen (CHN) (0–5–2)                                  NaN
# 5          Paavo Nurmi (FIN) (9–3–0)            Paavo Nurmi (FIN) (9–3–0)
# 6                                NaN             Carl Lewis (USA) (9–1–0)
# 7             Gao Ling (CHN) (2–1–1)               Gao Ling (CHN) (2–1–1)
# 8                                NaN             Fu Haifeng (CHN) (2–1–0)
# 9                                NaN         Viktor Axelsen (DEN) (2–0–1)

# %% [markdown]
# Very messy. Let's start with building a list of what we want our column names to be. Then,

# %%
columns = ['Discipline', 'Contested', 'Number of Olympics', 'Medal Events', '# of Gold MedalsP']

# %% [markdown]
# ## Dataset #2: Covid Cases

# %%
covid_untidy = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")

covid_untidy.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN           Antarctica -71.94990   23.347000
# 6                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 7                           NaN            Argentina -38.41610  -63.616700
# 8                           NaN              Armenia  40.06910   45.038200
# 9  Australian Capital Territory            Australia -35.47350  149.012400
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...   2/28/23  \
# 0        0        0        0        0        0        0  ...    209322
# 1        0        0        0        0        0        0  ...    334391
# 2        0        0        0        0        0        0  ...    271441
# 3        0        0        0        0        0        0  ...     47866
# 4        0        0        0        0        0        0  ...    105255
# 5        0        0        0        0        0        0  ...        11
# 6        0        0        0        0        0        0  ...      9106
# 7        0        0        0        0        0        0  ...  10044125
# 8        0        0        0        0        0        0  ...    446819
# 9        0        0        0        0        0        0  ...    232018
#
#      3/1/23    3/2/23    3/3/23    3/4/23    3/5/23    3/6/23    3/7/23  \
# 0    209340    209358    209362    209369    209390    209406    209436
# 1    334408    334408    334427    334427    334427    334427    334427
# 2    271448    271463    271469    271469    271477    271477    271490
# 3     47875     47875     47875     47875     47875     47875     47875
# 4    105277    105277    105277    105277    105277    105277    105277
# 5        11        11        11        11        11        11        11
# 6      9106      9106      9106      9106      9106      9106      9106
# 7  10044125  10044125  10044125  10044125  10044125  10044957  10044957
# 8    446819    446819    446819    446819    446819    446819    446819
# 9    232018    232619    232619    232619    232619    232619    232619
#
#      3/8/23    3/9/23
# 0    209451    209451
# 1    334443    334457
# 2    271494    271496
# 3     47890     47890
# 4    105288    105288
# 5        11        11
# 6      9106      9106
# 7  10044957  10044957
# 8    447308    447308
# 9    232619    232974
#
# [10 rows x 1147 columns]

# %%
covid_tidy = covid_untidy.melt(id_vars=["Province/State", "Country/Region", "Lat", "Long"], var_name="Date", value_name="Cases")
covid_tidy["Date"] = pd.to_datetime(covid_tidy["Date"])
covid_tidy.sort_values(by=["Country/Region", "Date"]).head(10)
# Out:
# /tmp/ipykernel_1844/3915466402.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   covid_tidy["Date"] = pd.to_datetime(covid_tidy["Date"])
#      Province/State Country/Region       Lat       Long       Date  Cases
# 0               NaN    Afghanistan  33.93911  67.709953 2020-01-22      0
# 289             NaN    Afghanistan  33.93911  67.709953 2020-01-23      0
# 578             NaN    Afghanistan  33.93911  67.709953 2020-01-24      0
# 867             NaN    Afghanistan  33.93911  67.709953 2020-01-25      0
# 1156            NaN    Afghanistan  33.93911  67.709953 2020-01-26      0
# 1445            NaN    Afghanistan  33.93911  67.709953 2020-01-27      0
# 1734            NaN    Afghanistan  33.93911  67.709953 2020-01-28      0
# 2023            NaN    Afghanistan  33.93911  67.709953 2020-01-29      0
# 2312            NaN    Afghanistan  33.93911  67.709953 2020-01-30      0
# 2601            NaN    Afghanistan  33.93911  67.709953 2020-01-31      0
